# %% [markdown]
# # CS7641 Machine Learning
# ### <i>Application of Machine Learning in Pairs Trading</i>

# %% [markdown]
# ## Data Filtering
# Our dataset contains two datasets: daily stock price data and monthly firm-level financial ratios data. We preselect stocks from Russel 3000 which can idealy represent 98% of total market shares of the U.S. Equity Market. Then we perform basic data screening and stock filtering to eliminate stocks that would affect our results.
#
# - Training set sample period: 2010/01/01 to 2015/12/31, use for clustering and training trading model
# - Testing period: 2016/01/01 to 2019/12/31, use for testing trading model
#
# ### 1. Daily Stock Price Dataset
#  - Delete stocks that are delisted during sample period (since we cannot trade them anymore)
#  - Delete stocks that have negative stock price during sample period (will be problematic when trading)
#  - Delete stocks that have long-time low trading volumn (avoid illiquidity trap)
#  - Delete stocks that have more than half missing data (avoid funtionality error for PCA)
#
# This left us with 2060 stocks in total.
#
# ### 2. Monthly Financial Ratios Dataset
# We use 20 financial ratios, including
#  - Asset Turnover
#  - BM (Book/Market)
#  - Capitalization Ratio
#  - Cash Flow/Total Debt
#  - Cash Flow Margin
#  - Current Ratio
#  - DE ratio (Total Debt/Equity)
#  - Total Debt/EBITDA
#  - Free Cash Flow/Operating Cash Flow
#  - Gross Profit/Total Assets
#  - Interest Coverage Ratio
#  - Long-term Debt/Total Liabilities
#  - Net Profit Margin
#  - P/E (Diluted, Excluding El)
#  - Pre-tax Return on Total Earning Assets
#  - Return on Assets
#  - Return on Equity
#  - Price/Book
#  - Quick Ratio
#  - Total Debt/Invested Capital
#
# We may exclude some ratios if their are too many missing data

# %%
import pandas as pd
import numpy as np
import os
import datetime
import missingno as msno
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b557fa0421b2> in <module>
#       3 import os
#       4 import datetime
# ----> 5 import missingno as msno
#
# ModuleNotFoundError: No module named 'missingno'

# %% [markdown]
# ### 1. Stock Price

# %%
#import stock price dataset
price = pd.read_csv("~/Downloads/russel3000PriceDaily.csv")
# Out:
# /Users/Sharonvy/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (2,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#take a glance of original price dataset
price.head()
# Out:
#    PERMNO      date SICCD TICKER  DLSTCD    PRC       VOL        RET  SHROUT  \
# 0   10025  20070103  3070   AEPI     NaN  49.06  112525.0  -0.079722  7886.0
# 1   10025  20070104  3070   AEPI     NaN  50.34   87697.0   0.026090  7886.0
# 2   10025  20070105  3070   AEPI     NaN  49.63   43162.0  -0.014104  7886.0
# 3   10025  20070108  3070   AEPI     NaN  49.50   37778.0  -0.002619  7886.0
# 4   10025  20070109  3070   AEPI     NaN  50.62   40393.0   0.022626  7886.0
#
#         RETX
# 0  -0.079722
# 1   0.026090
# 2  -0.014104
# 3  -0.002619
# 4   0.022626

# %%
print("Original dataset size: ", len(price))
print("Original number of stocks: ", len(set(price['PERMNO'])))
# Out:
# Original dataset size:  8497689
# Original number of stocks:  3292

# %%
#preprocessing
price['_date'] = pd.to_datetime(price['date'], format = '%Y%m%d')
price['turnover'] = price['VOL']/price['SHROUT']

#delisted stocks
dlst = price[price['DLSTCD'] >= 300]        #those are companies that are liquidated, dropped or exhanged during sample period
dlst_list = list(set(dlst['PERMNO']))       #and should be exclude in our training set (since we cannot trade them anymore)

#negative price stocks
neg_price = price[price['PRC'] <= 0]        #delete stocks with negative price (will be problematic when trading)
neg_price_list = list(set(neg_price['PERMNO']))

#low trading volume
low_vol = price[price['turnover'] <= 0.1]   #if the daily trading volume is less than 0.1% of its total shares outstanding
low_vol_list = list(set(low_vol['PERMNO']))
for item in low_vol_list:
    temp = low_vol.loc[low_vol['PERMNO'] == item]
    if len(temp) < 100:                     #avoid deleting too many stocks (data collection error or temporary derail)
        low_vol_list.remove(item)

# %%
#stocks that we want to exclude
final_list = list(set(dlst_list) | set(neg_price_list) | set(low_vol_list))
#final dataset for price
stock_price = price.loc[price['PERMNO'].isin(final_list) == False]

# %%
print("Dataset size: ", len(stock_price))
print("Number of stocks: ", len(set(stock_price['PERMNO'])))
# Out:
# Dataset size:  7255941
# Number of stocks:  2740

# %%
#set training set sample period for clsutering analysis, from 2010/01/01 to 2015/12/31
#and set testing dataset from 2016/01/01 to 2019/12/31
price_train = stock_price.loc[stock_price['date'] < 20160101]
price_test = stock_price.loc[stock_price['date'] >= 20160101]

# %%
#get the pivot table, with stock permno as index and datetime as columns
df_price = pd.pivot_table(price_train, values = 'PRC', index = 'PERMNO', columns = 'date')
df_price = df_price.add_prefix('price_')
#last step, delete stocks with more than half nan price for clustering
df_price = df_price.dropna(thresh = len(df_price.columns)//2)
df_price = df_price.fillna(method = 'ffill', axis = 1, limit = 5)

# %%
df_price.head()
# Out:
# date    price_20070103  price_20070104  price_20070105  price_20070108  \
# PERMNO
# 10025            49.06           50.34           49.63           49.50
# 10026            41.02           41.89           39.66           40.42
# 10032            24.12           24.30           23.89           23.70
# 10051             7.40            7.33            7.52            7.44
# 10104            17.51           17.68           17.64           17.86
#
# date    price_20070109  price_20070110  price_20070111  price_20070112  \
# PERMNO
# 10025            50.62           49.68           49.20           48.90
# 10026            40.54           41.54           41.41           42.23
# 10032            23.13           20.90           20.84           21.58
# 10051             7.51            7.52            7.45            7.60
# 10104            17.82           17.77           17.39           17.50
#
# date    price_20070116  price_20070117  ...  price_20151217  price_20151218  \
# PERMNO                                  ...
# 10025            46.83           47.05  ...           80.80           79.01
# 10026            41.71           41.28  ...          114.37          112.69
# 10032            20.79           20.58  ...           35.26           34.99
# 10051             7.83            7.82  ...           17.53           16.77
# 10104            17.30           17.52  ...           36.93           36.35
#
# date    price_20151221  price_20151222  price_20151223  price_20151224  \
# PERMNO
# 10025            76.40           77.93           78.98           80.55
# 10026           112.92          114.53          115.90          118.21
# 10032            35.22           35.08           35.95           36.05
# 10051            16.52           17.08           17.29           17.38
# 10104            36.42           36.59           36.93           37.01
#
# date    price_20151228  price_20151229  price_20151230  price_20151231
# PERMNO
# 10025            78.97           77.15           77.22           77.15
# 10026           117.64          119.37          119.25          116.67
# 10032            35.67           35.92           35.46           34.92
# 10051            16.96           16.95           16.85           16.45
# 10104            36.79           37.04           36.92           36.53
#
# [5 rows x 2266 columns]

# %%
print("Number of training stocks: ", len(df_price))
# Out:
# Number of training stocks:  2105

# %%
#get the list permno for further data extraction
permno = list(df_price.index)
with open('permno_list.txt', 'w') as filehandle:    #write to file
    for listitem in permno:
        filehandle.write('%i\n' % listitem)

# %%
df_price.to_csv('stock_price_table.csv')

# %% [markdown]
# ### 2. Financial Ratios

# %%
#import financial ratios dataset
ratios = pd.read_csv("~/Downloads/financialRatiosMonthly_new.csv")
ratios.head()
# Out:
#    permno       adate     qdate  public_date     bm  pe_exi    npm    cfm  \
# 0   10025  20091031.0  20091031     20100131  0.365   7.845  0.041  0.068
# 1   10025  20091031.0  20091031     20100228  0.365   7.843  0.041  0.068
# 2   10025  20091031.0  20100131     20100331  0.338  13.208  0.019  0.047
# 3   10025  20091031.0  20100131     20100430  0.338  14.025  0.019  0.047
# 4   10025  20091031.0  20100131     20100531  0.338  12.761  0.019  0.047
#
#      roa    roe  GProf  totdebt_invcap  capital_ratio  debt_ebitda  lt_debt  \
# 0  0.212  0.473  0.498           0.704          0.698        2.221    0.615
# 1  0.212  0.473  0.498           0.704          0.698        2.221    0.615
# 2  0.148  0.183  0.427           0.727          0.722        3.620    0.657
# 3  0.148  0.183  0.427           0.727          0.722        3.620    0.657
# 4  0.148  0.183  0.427           0.727          0.722        3.620    0.657
#
#    cash_debt  fcf_ocf  de_ratio  at_turn    ptb
# 0       0.31    0.729     3.750    1.984  2.740
# 1       0.31    0.729     3.750    1.984  2.740
# 2       0.31    0.289     3.963    2.055  2.204
# 3       0.31    0.289     3.963    2.055  2.340
# 4       0.31    0.289     3.963    2.055  2.129

# %%
#since the public date is already two month behind qdate (defined to be), we do not need to lag the data anymore
ratios['_date'] = pd.to_datetime(ratios['public_date'], format = '%Y%m%d').dt.to_period('M')
#select only training period
ratios_train = ratios.loc[(ratios['public_date'] >= 20151201) & (ratios['public_date']<= 20151231)]
ratios_train.tail()
# Out:
#         permno       adate     qdate  public_date     bm   pe_exi    npm  \
# 210297   93423  20141231.0  20150930     20151231  0.095   45.783  0.096
# 210409   93426  20141231.0  20150930     20151231  1.229  -34.303 -0.019
# 210522   93428  20141231.0  20150930     20151231  0.284 -392.890 -0.009
# 210612   93429  20141231.0  20150930     20151231  0.049   26.708  0.316
# 210725   93436  20141231.0  20150930     20151231  0.040  -45.030 -0.178
#
#           cfm    roa    roe  ...  totdebt_invcap  capital_ratio  debt_ebitda  \
# 210297  0.217  0.159  0.292  ...           0.718          0.900        3.557
# 210409  0.030  0.077 -0.022  ...           0.102          0.062        0.963
# 210522  0.050  0.057 -0.010  ...           0.342          0.342        4.661
# 210612  0.386  1.010  0.799  ...           0.000          0.000        0.000
# 210725 -0.087 -0.031 -0.791  ...           0.876          0.659      -13.879
#
#         lt_debt  cash_debt  fcf_ocf  de_ratio  at_turn     ptb    _date
# 210297    0.726      0.209    0.768    12.406    0.472  12.501  2015-12
# 210409    0.160      0.270    0.305     0.416    0.847   0.733  2015-12
# 210522    0.466      0.243    0.702     1.117    0.521   4.192  2015-12
# 210612    0.000      1.963    0.864     0.549    1.698  19.610  2015-12
# 210725    0.350     -0.012      NaN     5.533    0.583  23.994  2015-12
#
# [5 rows x 21 columns]

# %%
#visualize missing data
msno.matrix(ratios_train)

# %%
ratio_cols = ['permno'] + list(ratios_train.columns[4:-1])

# %%
#select only those columns
ratios_data = ratios_train.loc[:,ratios_train.columns.isin(ratio_cols)].reset_index(drop = True)
ratios_data.head()
# Out:
#    permno     bm   pe_exi    npm    cfm    roa    roe  GProf  totdebt_invcap  \
# 0   10025  0.273   13.679  0.025  0.054  0.210  0.308  0.484           0.710
# 1   10026  0.303   31.279  0.072  0.111  0.205  0.112  0.456           0.002
# 2   10032  0.659   12.745  0.036  0.054  0.100  0.115  0.169           0.239
# 3   10051  0.981 -548.330 -0.001  0.037  0.058 -0.002  0.058           0.553
# 4   10104  0.297   17.070  0.250  0.326  0.164  0.198  0.298           0.443
#
#    capital_ratio  debt_ebitda  lt_debt  cash_debt  fcf_ocf  de_ratio  at_turn  \
# 0          0.702        2.296    0.602      0.201    0.827     3.910    2.573
# 1          0.002        0.010    0.008      0.736    0.524     0.238    1.349
# 2          0.235        1.588    0.301      0.089    0.542     1.021    1.603
# 3          0.524        7.474    0.658      0.061    0.373     1.675    0.834
# 4          0.427        2.221    0.635      0.232    0.878     1.173    0.365
#
#      ptb
# 0  3.534
# 1  3.385
# 2  1.364
# 3  1.216
# 4  3.259

# %%
print("Number of stocks in ratios dataset: ", len(ratios_data))
# Out:
# Number of stocks in ratios dataset:  1795

# %%
#save training set to file
ratios_data.to_csv('ratios_data_table.csv')

# %%
#filtering stocks for testing dataset
testing_set = price_test.loc[price_test['PERMNO'].isin(list(set(ratios['permno'])))]
testing_set.head()
# Out:
#       PERMNO      date SICCD TICKER  DLSTCD    PRC      VOL        RET  \
# 2266   10025  20160104  3081   AEPI     NaN  73.19  29246.0  -0.051329
# 2267   10025  20160105  3081   AEPI     NaN  74.40  56220.0   0.016532
# 2268   10025  20160106  3081   AEPI     NaN  77.49  53924.0   0.041532
# 2269   10025  20160107  3081   AEPI     NaN  74.50  20810.0  -0.038586
# 2270   10025  20160108  3081   AEPI     NaN  74.82  47478.0   0.004295
#
#       SHROUT       RETX      _date   turnover
# 2266  5103.0  -0.051329 2016-01-04   5.731139
# 2267  5103.0   0.016532 2016-01-05  11.017049
# 2268  5103.0   0.041532 2016-01-06  10.567117
# 2269  5103.0  -0.038586 2016-01-07   4.077993
# 2270  5103.0   0.004295 2016-01-08   9.303939

# %%
testing_set.to_csv('tetsing_data.csv')
