# %%
import pandas as pd
import numpy as np
import os
import datetime

# %%
#import training dataset
trdt = pd.read_csv("training_data.csv")
print("\nNumber of stocks (rows):", len(trdt))
print("\nNumber of days (columns):", len(trdt.columns))
# Out:
# Number of stocks (rows): 2060
#
# Number of days (columns): 3635

# %%
trdt.head(10)
# Out:
#    PERMNO  price_20070103  price_20070104  price_20070105  price_20070108  \
# 0   10025           49.06           50.34           49.63           49.50
# 1   10026           41.02           41.89           39.66           40.42
# 2   10032           24.12           24.30           23.89           23.70
# 3   10051            7.40            7.33            7.52            7.44
# 4   10104           17.51           17.68           17.64           17.86
# 5   10107           29.86           29.81           29.64           29.93
# 6   10138           45.75           46.15           46.06           46.90
# 7   10145           45.10           45.08           44.65           44.92
# 8   10147           13.20           13.53           13.61           14.08
# 9   10158             NaN             NaN             NaN             NaN
#
#    price_20070109  price_20070110  price_20070111  price_20070112  \
# 0           50.62           49.68           49.20           48.90
# ...

# %%
#transpose the dataset
train=trdt.T
print("\nNumber of days:", len(train.columns))
print("\nNumber of stocks:", len(train))
# Out:
# Number of days: 2060
#
# Number of stocks: 3635

# %%
train.head()
# Out:
#                     0         1         2         3         4         5     \
# PERMNO          10025.00  10026.00  10032.00  10051.00  10104.00  10107.00
# price_20070103     49.06     41.02     24.12      7.40     17.51     29.86
# price_20070104     50.34     41.89     24.30      7.33     17.68     29.81
# price_20070105     49.63     39.66     23.89      7.52     17.64     29.64
# price_20070108     49.50     40.42     23.70      7.44     17.86     29.93
#
#                     6         7         8        9     ...     2050     2051  \
# PERMNO          10138.00  10145.00  10147.00  10158.0  ...  93384.0  93397.0
# price_20070103     45.75     45.10     13.20      NaN  ...      NaN      NaN
# price_20070104     46.15     45.08     13.53      NaN  ...      NaN      NaN
# price_20070105     46.06     44.65     13.61      NaN  ...      NaN      NaN
# price_20070108     46.90     44.92     14.08      NaN  ...      NaN      NaN
#
# ...

# %%
train.fillna(train.mean(), inplace=True)

# %%
train.head()
# Out:
#                     0         1         2         3         4         5     \
# PERMNO          10025.00  10026.00  10032.00  10051.00  10104.00  10107.00
# price_20070103     49.06     41.02     24.12      7.40     17.51     29.86
# price_20070104     50.34     41.89     24.30      7.33     17.68     29.81
# price_20070105     49.63     39.66     23.89      7.52     17.64     29.64
# price_20070108     49.50     40.42     23.70      7.44     17.86     29.93
#
#                     6         7         8             9     ...          2050  \
# PERMNO          10138.00  10145.00  10147.00  10158.000000  ...  93384.000000
# price_20070103     45.75     45.10     13.20     10.381634  ...     50.584819
# price_20070104     46.15     45.08     13.53     10.381634  ...     50.584819
# price_20070105     46.06     44.65     13.61     10.381634  ...     50.584819
# price_20070108     46.90     44.92     14.08     10.381634  ...     50.584819
#
# ...

# %%
train.to_csv('imputedtrainT.csv')

# %%
#Transpsose again
imtr=train.T

# %%
imtr.to_csv('imputedtrain.csv')

# %%
imtr.head(12)
# Out:
#      PERMNO  price_20070103  price_20070104  price_20070105  price_20070108  \
# 0   10025.0       49.060000       50.340000       49.630000       49.500000
# 1   10026.0       41.020000       41.890000       39.660000       40.420000
# 2   10032.0       24.120000       24.300000       23.890000       23.700000
# 3   10051.0        7.400000        7.330000        7.520000        7.440000
# 4   10104.0       17.510000       17.680000       17.640000       17.860000
# 5   10107.0       29.860000       29.810000       29.640000       29.930000
# 6   10138.0       45.750000       46.150000       46.060000       46.900000
# 7   10145.0       45.100000       45.080000       44.650000       44.920000
# 8   10147.0       13.200000       13.530000       13.610000       14.080000
# 9   10158.0       10.381634       10.381634       10.381634       10.381634
# 10  10180.0        5.890000        5.600000        5.560000        5.600000
# ...

# %%
from sklearn.preprocessing import StandardScaler
x = StandardScaler().fit_transform(imtr)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x[0][0:10]
# Out:
# array([-2.13369025,  0.31168446,  0.34280627,  0.33432249,  0.33023521,
#         0.35717566,  0.32751126,  0.30437271,  0.28887314,  0.23519578])

# %%
k=20

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=k)
principalComponents = pca.fit_transform(x)

# %%
Red = pd.DataFrame(data = principalComponents
             , columns = range(1,k+1))

# %%
type(Red)
# Out:
# pandas.core.frame.DataFrame

# %%
Red.head(12)
# Out:
#             1          2          3          4         5         6         7  \
# 0   -0.368007 -10.064990   3.258395  -2.064776 -0.122476  0.437417 -1.691441
# 1   17.263404 -15.265948  10.377799  -0.592472 -1.264367  3.611386  5.703059
# 2   -9.257404  -8.886697   1.729462  -3.045100  0.280410 -2.013369  2.178735
# 3  -19.297072  -6.340624   4.602733  -2.218209  0.543421 -3.878398  2.416317
# 4  -10.685237  -8.160566   3.739268  -2.239043  0.135653 -2.134893  2.601398
# 5   -8.020903  -8.653002   0.005172  -1.563774 -0.549772  1.038135  1.699081
# 6   25.420029  -8.941868  -2.207598  10.907168 -0.051934 -8.921308 -1.016756
# 7   21.675577 -15.951976   4.007436  -3.195450 -1.019994  5.279898 -0.985322
# 8  -18.030978  -6.541919   3.459708  -2.620671  0.323330 -2.619319  0.525366
# 9  -28.664099  -3.491453   0.243101  -1.646923 -0.002599 -2.793716  2.786971
# 10 -28.555010  -3.558559   9.799527   2.092125 -1.507783  3.573766 -0.033424
# ...

# %%
len(Red)
# Out:
# 2060

# %%
len(Red.columns)
# Out:
# 20

# %%
Red.to_csv('Reducedtrain.csv')
